# %%
import urllib.request
from urllib.parse import quote_plus
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
import time
import requests
import pandas as pd
import unicodedata

# %%
driver = webdriver.Chrome('C:/Users/LG/Desktop/21winter/YBIGTA/edu_session/0202 크롤링/chromedriver.exe')
# driver_2 = webdriver.Chrome('C:/Users/LG/Desktop/21winter/YBIGTA/edu_session/0202 크롤링/chromedriver.exe')

# %%
driver.get('https://instagram.com/explore')
time.sleep(1)

driver.find_element_by_name('username').send_keys('01088797388')
driver.find_element_by_name('password').send_keys('jc041794')
driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]/button').click()

# %%
url="https://www.instagram.com/explore/tags/"
tag = "제주도"
url = url + quote_plus(tag)
driver.get(url)

time.sleep(3)

html = driver.page_source
soup = bs(html, 'lxml')

# insta = soup.select('.v1Nh3.kIKUG._bz0w')
# insta

# %%
how_many_scroll = 20

# how_many_scroll만큼 맨 밑으로 스크롤하고 맨 위로 돌아오기
for _ in range(how_many_scroll):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(1)
driver.execute_script('window.scrollTo(0,0);')

# 첫 번째 게시물
driver.find_element_by_class_name('_9AhH0').click()

# %%
image_name_list = []
image_url_list = []
contents_list = []
location_list = []
hashtags_list = []

# %%
# 이미지를 따로 보관할 'img'라는 디렉토리를 미리 생성
how_many_crawl = 3


for i in range(how_many_crawl):
    html = driver.page_source
    soup = bs(html, 'lxml')
    time.sleep(1)
    
    img_url = soup.select('.KL4Bh')[n].img['src']
    image_name = 'test_' + str(n) + '.jpg'
    with urllib.request.urlopen(img_url) as f:
        with open('./img/' + 'test_' + str(n) + '.jpg', 'wb') as h:
            img = f.read()
            h.write(img)

    location = driver.find_elements_by_class_name('O4GlU')
    if len(location) == 0:
        location = ''
    else:
        location = location[0].text.replace(',',' ')
        
    contents = driver.find_elements_by_xpath('/html/body/div[5]/div[2]/div/article/div[3]/div[1]/ul/div/li/div/div/div[2]/span')
    if len(contents) == 0:
        contents = ''
    else:
        contents = contents[0].text.split('#')[0]
    
    # 답글 열기 - test
    replies = driver.find_elements_by_class_name('EizgU')
    for reply in replies:
        reply.click()
    time.sleep(1)
    
    hashtags = ''
    tag_list = driver.find_elements_by_class_name('xil3i')
    for k in range(len(tag_list)):
        hashtags += tag_list[k].text
        
    image_url_list.append(img_url)
    image_name_list.append(image_name)
    location_list.append(location)
    hashtags_list.append(hashtags)
    contents_list.append(contents)
    
    # 다음 게시물
    driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow').click()
    time.sleep(1)
    n += 1

# %%
# 자음 모음 분리 현상 해결
for i in range(len(contents_list)):
    contents_list[i] = unicodedata.normalize('NFC', contents_list[i])
for i in range(len(location_list)):
    location_list[i] = unicodedata.normalize('NFC', location_list[i])    
for i in range(len(hashtags_list)):
    hashtags_list[i] = unicodedata.normalize('NFC', hashtags_list[i])

# %%
dictionary = {'image_name':image_name_list,
             'image_url':image_url_list,
             'contents':contents_list,
             'location':location_list,
             'hashtags':hashtags_list}
df = pd.DataFrame(dictionary)
df
# Out:
#      image_name                                          image_url  \
# 0    test_0.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 1    test_1.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 2    test_2.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 3    test_3.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 4    test_4.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 5    test_0.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 6    test_1.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 7    test_2.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 8    test_3.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 9    test_4.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 10   test_5.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 11   test_6.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 12   test_7.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 13   test_8.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 14   test_9.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 15  test_10.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 16  test_11.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 17  test_12.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 18  test_13.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 19  test_14.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 20  test_15.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 21  test_16.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 22  test_17.jpg  https://scontent-ssn1-1.cdninstagram.com/v/t51...
#
#                                              contents  \
# 0
# 1                                             잡았다 요놈!
# 2   .\n반도 다르고 성격도 다르고\n어찌 친해진지도 모르겠고\n알다가도 모르겠는 요아...
# 3
# 4
# 5
# 6                                             잡았다 요놈!
# 7   .\n반도 다르고 성격도 다르고\n어찌 친해진지도 모르겠고\n알다가도 모르겠는 요아...
# 8
# 9
# 10                                             유미♥️남운
# 11
# 12  우리 마니오빠의 초대로 급 제주도~~~\n쉬지 않고 먹고 수다 떨고~~\n오랫만에 ...
# 13                    제주도스러운 사진을\n건지고 싶어서 찍었었던. .\n\n
# 14
# 15  제주 서쪽 바다.\n깨끗한데 바람이 강해서 파도도 쎄다.\n덕분에 멋진 파도 구경할...
# 16                                                 🐶🐶
# 17          중문 엉덩물 계곡\n예년만큼 많이 피진 안았지만\n그래도 봄향기 남\n\n
# 18  우리 여행목표\n1. 싸우지않기\n(tmi)...아직 안 싸움\n(또tmi)...해...
# 19                               제주를 담다, 잔. 디. 우. 유\n
# 20                                         어제 2일차 하루
# 21
# 22  ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀\n⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀\n\n첫 단추도 잘 끼워야 ...
#
#                                        location  \
# 0
# 1                                          금악오름
# 2                         Busan 釜山  South Korea
# 3                                          Jeju
# 4
# 5
# 6                                          금악오름
# 7                         Busan 釜山  South Korea
# 8                                          Jeju
# 9
# 10                      LOTTE HOTEL JEJU 롯데호텔제주
# 11
# 12
# 13
# 14  Gimpo International Airport - 金浦国际机场 - 김포공항
# 15                                     Seogwipo
# 16
# 17
# 18                                        산방산근처
# 19                                         잔디공장
# 20
# 21                                        리하의커리
# 22
#
#                                              hashtags
# 0   #98년생#24살#대구#칠곡3지구#동성로#제주#제주도#제주도여행#까멜리아힐#동백꽃#...
# 1
# 2
# 3                                              #앞머리생성
# 4            #잠깐#여유#뱅기#하늘#구름#석양#제주도#답답한마음#걸어온이길이#흔들릴때
# 5   #98년생#24살#대구#칠곡3지구#동성로#제주#제주도#제주도여행#까멜리아힐#동백꽃#...
# 6
# 7
# 8   #앞머리생성#셀스타그램#셀카#셀피#selca#selfie#ootd#인스타그램#ins...
# 9            #잠깐#여유#뱅기#하늘#구름#석양#제주도#답답한마음#걸어온이길이#흔들릴때
# 10  #셀피#소통#팔로우#좋아요테러#럽스타그램#좋아요#럽스타#f4f#연애스타그램#self...
# 11  #Repost#대구#마리스포사#수입드레스#드레스맛집#웨딩박람회#대봉동#김광석거리#촬...
# 12                     #제주도#찐친#남친아니고#우리오빠임#추억소환#수다삼매경
# 13        #제주도#jeju#하르방#사진#여행#지나간시간#따뜻할때가고싶다#힐링#천지연폭포
# 14                               #제주로향함#영실어리목#트래킹#제주도
# 15  #제주올레12길#제주서쪽#제주도#제주여행#올레12길#파도#pado#ahn_kim_w...
# 16  #dog#dogstagram#doglife#doglover#doggy#dogsofi...
# 17  #사진#여행#여행사진#제주#제주도#제주사진#일상#제주일상#제주살이#아이포12프로맥스...
# 18  #제주#제주도#협재해수욕장#애월#서귀포#뷰스트#카페#돌하르방#산방산유채꽃밭#사계해변...
# 19  #제주도#성산카페#잔디공장#잔디우유#제주#서귀포#카페#식물카페#서귀포카페#성산일출봉...
# 20                   #22#00#daily#제주도#여행#카멜리아힐#아르떼뮤지엄
# 21  #재료소진#탈탈다털렸어요#시간대비최고매출갱신#난리났네난리났어#마지막후라이팬돌리는중#...
# 22  #출근#퇴근#주말#직딩#직장인#재무설계사#자산관리사#드라이브#코로나#날씨#부평#강남...

# %%
df.to_csv("data_list.csv", index=True, encoding='utf-8-sig')

# %%
""
